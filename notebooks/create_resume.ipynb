# %%
import sys
import os
import warnings

sys.path.append(
    os.path.abspath(os.path.join(os.path.dirname(os.path.realpath("__file__")), ".."))
)

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
import pandas as pd
import numpy as np

# %%
configs = os.path.join(
    os.path.abspath(os.path.join(os.path.dirname(os.path.realpath("__file__")), "..")),
    "inputs",
    "dummy.json",
)

# %%
from latex.resume import Resume

r = Resume(file_path=configs)

# %%
r.create_resume(select_experiences=None)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./resume.tex
# LaTeX2e <2023-11-01> patch level 1
# L3 programming layer <2024-02-20>
# (./resume.cls
# Document Class: resume 2010/07/10 v0.9 Resume class
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2023/05/17 v1.4n Standard LaTeX document class
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/base/size11.clo))
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/parskip/parskip.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/etoolbox/etoolbox.sty))
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/tools/array.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/base/ifthen.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/graphics-def/pdftex.def)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/graphics/mathcolor.ltx))
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/xcolor/x11nam.def)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/hyperref/hyperref.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/iftex/iftex.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.
# sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/pdfescape/pdfescape.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/infwarerr/infwarerr.sty)))
#  (/usr/local/texlive/2024basic/texmf-dist/tex/latex/hycolor/hycolor.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/auxhook/auxhook.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/hyperref/nameref.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/refcount/refcount.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/gettitlestring/gettitlestr
# ing.sty))
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/hyperref/pd1enc.def)
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/intcalc/intcalc.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/hyperref/puenc.def)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/url/url.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/bitset/bitset.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/bigintcalc/bigintcalc.sty)
# ) (/usr/local/texlive/2024basic/texmf-dist/tex/latex/base/atbegshi-ltx.sty))
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/hyperref/hpdftex.def
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/base/atveryend-ltx.sty)
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/rerunfilecheck/rerunfilechec
# k.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/uniquecounter/uniquecounte
# r.sty))))
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2024basic/texmf-dist/tex/generic/iftex/ifvtex.sty))
# (/usr/local/texlive/2024basic/texmf-dist/tex/latex/l3backend/l3backend-pdftex.d
# ef)
# No file resume.aux.
# (/usr/local/texlive/2024basic/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
#
# Overfull \hbox (30.0pt too wide) in paragraph at lines 16--16
# []
#
# ! LaTeX Error: \begin{document} ended by \end{rSection}.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.21 \end{tabular}\end{rSection}
#
# ! Extra \endgroup.
# <recently read> \endgroup
#
# l.21 \end{tabular}\end{rSection}
#
#
# ! LaTeX Error: \begin{document} ended by \end{rSection}.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.39 \end{itemize}\end{rSection}
#
# ! Extra \endgroup.
# <recently read> \endgroup
#
# l.39 \end{itemize}\end{rSection}
#
# [1{/usr/local/texlive/2024basic/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./resume.aux)
#
# Package rerunfilecheck Warning: File `resume.out' has changed.
# (rerunfilecheck)                Rerun to get outlines right
# (rerunfilecheck)                or use package `bookmark'.
#
#  )
# (see the transcript file for additional information) </Users/timbastian/Library
# /texlive/2024basic/texmf-var/fonts/pk/ljfour/jknappen/ec/tcrm1095.600pk></usr/l
# ocal/texlive/2024basic/texmf-dist/fonts/type1/public/amsfonts/cm/cmbx10.pfb></u
# sr/local/texlive/2024basic/texmf-dist/fonts/type1/public/amsfonts/cm/cmbx12.pfb
# ></usr/local/texlive/2024basic/texmf-dist/fonts/type1/public/amsfonts/cm/cmr10.
# pfb></usr/local/texlive/2024basic/texmf-dist/fonts/type1/public/amsfonts/cm/cms
# y10.pfb></usr/local/texlive/2024basic/texmf-dist/fonts/type1/public/amsfonts/cm
# /cmti10.pfb>
# Output written on resume.pdf (1 page, 66367 bytes).
# Transcript written on resume.log.

# %%
r.experience_data.data
# Out:
# [{'company': 'TestCorp',
#   'role': 'Software Engineer',
#   'start_date': '2020-01',
#   'end_date': '2021-12',
#   'location': 'Test City, TC',
#   'bullets': ['Developed internal tools', 'Improved CI/CD pipeline'],
#   'tags': ['python', 'devops']},
#  {'company': 'ExampleTech',
#   'role': 'Data Analyst',
#   'start_date': '2022-01',
#   'end_date': None,
#   'location': 'Example City, EC',
#   'bullets': ['Built dashboards', 'Analyzed customer data trends'],
#   'tags': ['sql', 'tableau']}]

# %%
print(r.tex)
# Out:
# \documentclass{resume}
# \usepackage[left=0.4in, top=0.4in, right=0.4in, bottom=0.4in]{geometry}
# \newcommand\blfootnote[1]{%
#   \begingroup
#   \renewcommand\thefootnote{}\footnote{#1}%
#   \addtocounter{footnote}{-1}%
#   \endgroup
# }
# \newcommand{\tab}[1]{\hspace{0.2667\textwidth}}
# \newcommand{\itab}[1]{\hspace{0em}}
#
# \name{Alice Doe}
# \address{+1-123-456-7890 \\ Test City, TC}
# \address{\href{mailto:alice.doe@example.com}{alice.doe@example.com} \\ \href{https://www.linkedin.com/in/alicedoe/}{https://www.linkedin.com/in/alicedoe/}}
#
# \begin{document}
# \rSection{SKILLS}
# \begin{tabular}{ @{} >{\bfseries}l @{\hspace{6ex}} p{0.8\textwidth} }
# Programming & python, Java, C++\\
# Data & Excel, SQL, Tableau\\
# \end{tabular}\end{rSection}
# \rSection{PROFESSIONAL EXPERIENCE}
#
# \textbf{Software Engineer} \hfill 2020-01 - 2021-12\\
# TestCorp \hfill \textit{Test City, TC}
# \vspace{-0.5em}
# \begin{itemize}
# \itemsep -6pt {}
# \item Developed internal tools
# \item Improved CI/CD pipeline
# \end{itemize}
# \textbf{Data Analyst} \hfill 2022-01 - current\\
# ExampleTech \hfill \textit{Example City, EC}
# \vspace{-0.5em}
# \begin{itemize}
# \itemsep -6pt {}
# \item Built dashboards
# \item Analyzed customer data trends
# \end{itemize}\end{rSection}
# \end{document}
